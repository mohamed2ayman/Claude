# %% [markdown]
# <a href="https://colab.research.google.com/github/mohamed2ayman/Claude/blob/main/Anthropic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Install dependencies
# %pip install anthropic python-dotenv

#Load New Variable

from dotenv import load_dotenv
load_dotenv()

# %%
#Install dependencies
# %pip install anthropic python-dotenv

#Load New Variable

from dotenv import load_dotenv
load_dotenv()

# Create API Client
import os
from anthropic import Anthropic

from google.colab import userdata
os.environ["ANTHROPIC_API_KEY"] = userdata.get('ANTHROPIC_API_KEY')

client = Anthropic()
model = "claude-sonnet-4-5"


# Make a request

message = client.messages.create(
    model = model,
    max_tokens = 1000,
    messages = [
        {
            "role":"user",
            "content": "what is quantum computing? Answer in one sentence"
        }


    ]



)

# %%
message.content[0].text
